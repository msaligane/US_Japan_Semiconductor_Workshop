# %% [markdown]
# <a href="https://colab.research.google.com/github/msaligane/US_Japan_Semiconductor_Workshop/blob/main/Day%202%20-%201505%20-%20Pitfalls%20of%20Open-Source%20Chip%20Design%20Verification/open_source_BE_verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pitfalls of Open-Source Chip Design Verification<br>オープンソース設計検証での注意点
# US-Japan Semiconductor Workshop, May 15th, 2024<br>最先端集積回路設計に関する日米連携ワークショップ 2024年5月15日
#
# D. Mitch Bailey　ShuhariSystem<br>ベイリー・デビッド　シュハリシステム

# %% [markdown]
# # Overview  概要
# Open source EDA software and systems such as OpenROAD, yosys, magic, xschem, klayout, iverilog, hgspice, etc., have made it possible for anyone to design and layout a mixed-signal chip. While the final step of verifying that the design matches the layout is possible with open source tools, there are pitfalls that you should be aware of. This workshop will provide hands-on experience with back-end verification using actual designs that were taped out on the Google funded open-MPW shuttles.
#
# OpenROAD, yosys, magic, xschem, klayout, iverilog, hgspice などのオープンソースソフトウェアやシステムのお陰で、誰でもがアナログやディジタルのチップを設計して、レイアウトすることができます。最終的のデザインとレイアウトの一致を確認するステップもオープンソースのツールでできますが要注意点があります。このワークショップでは実際にGoogleのOpen-MPWで出されたチップのデータを各自で検証できます。

# %% [markdown]
# # Google Open-MPW repos
# The Google open mpw repos are located [here](https://foss-eda-tools.googlesource.com/third_party/shuttle/sky130). There were 8 shuttles with 40 designs each, so there are 320 designs to choose from. The designs for each shuttle are summarized in a `manifest.csv` file of the `foundry` repo of each shuttle. For example, the list of designs for `mpw-003` are [here](https://foss-eda-tools.googlesource.com/third_party/shuttle/sky130/mpw-003/foundry/+/refs/heads/main/manifest-mpw-003.csv).
#
# GoogleのオープンMPWのrepoは[ここ](https://foss-eda-tools.googlesource.com/third_party/shuttle/sky130)にあります。8回のシャトルがあって、各シャトルに40個のチップが乗っていたので合計320デザインから選べます。各シャトルに乗っているデザインがそれぞれの`foundry` repoの`manifest.csv`にリストされています。例として、`mpw-003`のデザインリストは[ここ](https://foss-eda-tools.googlesource.com/third_party/shuttle/sky130/mpw-003/foundry/+/refs/heads/main/manifest-mpw-003.csv)にあります。
#
# For previously published results see the following discussions:<br>
# すでに発表された検証結果を以下で確認できます：
# * [sky130/mpw-002](https://github.com/d-m-bailey/extra_be_checks/discussions/26)
# * [sky130/mpw-003](https://github.com/d-m-bailey/extra_be_checks/discussions/27)
# * [sky130/mpw-004](https://github.com/d-m-bailey/extra_be_checks/discussions/35)
# * [sky130/mpw-006](https://github.com/d-m-bailey/extra_be_checks/discussions/39)

# %%
# %%writefile /content/env
# export PDK_ROOT=/content/pdks
# export PDK=sky130B
# export PDKPATH=$PDK_ROOT/$PDK
# export PRECHECK_ROOT=/content/mpw_precheck
# export CARAVEL_ROOT=/content/caravel
# export UPRJ_ROOT=/content/data
# export LVS_ROOT=/content/extra_be_checks
#
# export MPW=mpw-005
# export SLOT=slot-002
# export TOP=user_project_wrapper
# unset WORK_ROOT
# Out:
# Writing /content/env

# %% [markdown]
# # User setup
# Only needs to be executed once.
#
# This step sets up docker, pdk, precheck and creates a new user named lvs. <br><b>NOTE:</b> You will be prompted for a password - we suggest using lvs. Other info can be blank.

# %%
# %%shell
# cat /content/env
# source /content/env
# pip install udocker
# pip install volare
# udocker --allow-root install
# rm -rf mpw_precheck
# git clone https://github.com/efabless/mpw_precheck.git $PRECHECK_ROOT
# volare enable 6d4d11780c40b20ee63cc98e645307a9bf2b2ab8
# # remove unused pdk
# rm -rf $PDK_ROOT/sky130A
# rm -rf extra_be_checks
# git clone https://github.com/d-m-bailey/extra_be_checks.git -b 2406
# adduser lvs
# usermod -aG sudo lvs
# Out:
# export PDK_ROOT=/content/pdks
# export PDK=sky130B
# export PDKPATH=$PDK_ROOT/$PDK
# export PRECHECK_ROOT=/content/mpw_precheck
# export CARAVEL_ROOT=/content/caravel
# export UPRJ_ROOT=/content/data
# export LVS_ROOT=/content/extra_be_checks
#
# export MPW=mpw-005
# export SLOT=slot-002
# export TOP=user_project_wrapper
# unset WORK_ROOT
# Collecting udocker
#   Downloading udocker-1.3.16-py2.py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: udocker
# Successfully installed udocker-1.3.16
# Collecting volare
#   Downloading volare-0.17.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: click<9,>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from volare) (8.1.7)
# Requirement already satisfied: pyyaml<7,>=5 in /usr/local/lib/python3.10/dist-packages (from volare) (6.0.1)
# Requirement already satisfied: rich<14,>=12 in /usr/local/lib/python3.10/dist-packages (from volare) (13.7.1)
# Collecting httpx>=0.22.0 (from volare)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.4 MB/s eta 0:00:00
# Collecting pcpp<2,>=1.2 (from volare)
#   Downloading pcpp-1.30-py2.py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 9.8 MB/s eta 0:00:00
# Collecting zstandard<1,>=0.19.0 (from volare)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.22.0->volare) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.22.0->volare) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.22.0->volare)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.22.0->volare) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.22.0->volare) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.22.0->volare)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=12->volare) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=12->volare) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=12->volare) (0.1.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.22.0->volare) (1.2.1)
# Installing collected packages: pcpp, zstandard, h11, httpcore, httpx, volare
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 pcpp-1.30 volare-0.17.0 zstandard-0.22.0
# Info: creating repo: /root/.udocker
# Info: udocker command line interface 1.3.16
# Info: searching for udockertools >= 1.2.11
# Info: installing udockertools 1.2.11
# Info: installation of udockertools successful
# Cloning into '/content/mpw_precheck'...
# remote: Enumerating objects: 3803, done.
# remote: Counting objects: 100% (1091/1091), done.
# remote: Compressing objects: 100% (537/537), done.
# remote: Total 3803 (delta 595), reused 724 (delta 517), pack-reused 2712
# Receiving objects: 100% (3803/3803), 56.48 MiB | 14.91 MiB/s, done.
# Resolving deltas: 100% (2331/2331), done.
# Version 6d4d11780c40b20ee63cc98e645307a9bf2b2ab8 not found locally, attempting to download…
# Downloading common.tar.zst… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# ⠧ Unpacking common.tar.zst…
# Downloading sky130_fd_io.tar.zst… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# ⠇ Unpacking sky130_fd_io.tar.zst…
# Downloading sky130_fd_pr.tar.zst… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# ⠼ Unpacking sky130_fd_pr.tar.zst…
# Downloading sky130_fd_sc_hd.tar.zst… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# ⠦ Unpacking sky130_fd_sc_hd.tar.zst…
# Downloading sky130_fd_sc_hvl.tar.zst… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# ⠦ Unpacking sky130_fd_sc_hvl.tar.zst…
# Downloading sky130_ml_xx_hd.tar.zst… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# ⠋ Unpacking sky130_ml_xx_hd.tar.zst…
# Downloading sky130_sram_macros.tar.zst… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# ⠸ Unpacking sky130_sram_macros.tar.zst…
# ⠋ Enabling version 6d4d11780c40b20ee63cc98e645307a9bf2b2ab8…
# Version 6d4d11780c40b20ee63cc98e645307a9bf2b2ab8 enabled for the sky130 PDK.
# Cloning into 'extra_be_checks'...
# remote: Enumerating objects: 1094, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 1094 (delta 16), reused 16 (delta 16), pack-reused 1031
# Receiving objects: 100% (1094/1094), 780.45 KiB | 1.91 MiB/s, done.
# Resolving deltas: 100% (715/715), done.
# Adding user `lvs' ...
# Adding new group `lvs' (1000) ...
# Adding new user `lvs' (1000) with group `lvs' ...
# Creating home directory `/home/lvs' ...
# Copying files from `/etc/skel' ...
# New password:
# Retype new password:
# passwd: password updated successfully
# Changing the user information for lvs
# Enter the new value, or press ENTER for the default
# 	Full Name []:
# 	Room Number []:
# 	Work Phone []:
# 	Home Phone []:
# 	Other []:
# Is the information correct? [Y/n]

# %% [markdown]
# Create a script to extract the user_project_wrapper hierarchy as gds from the caravel oasis.
#
# Only needs to be run once.

# %%
# %%writefile oas2gds.py
import pya

app = pya.Application.instance()
opt = pya.SaveLayoutOptions()
layout_view = pya.Layout()

input_layout = "caravel.oas"
# Setting the name of the output file and setting the substitution character
print("[INFO] Reading from " + input_layout)

# Reading the input file and writing it to the output file name
layout_view.read(input_layout)
for cell_it in layout_view.each_cell():
    if cell_it.name.endswith("project_wrapper"):
        myIndex = layout_view.cell(cell_it.name).cell_index()
        output = "work/gds/" + cell_it.name + ".gds.gz"
        opt.set_format_from_filename(output)
        opt.oasis_substitution_char=''
        break
opt.select_cell(myIndex)
print("[INFO] Writing " + output)
layout_view.write(output, opt)

app.exit(0)
# Out:
# Writing oas2gds.py

# %% [markdown]
# # Clone the design repo and create gds.

# %%
# %%shell
# cat /content/env
# source /content/env
# rm -rf data
# git clone https://foss-eda-tools.googlesource.com/third_party/shuttle/sky130/$MPW/$SLOT.git data
# rm -rf data/.git data/tapeout/outputs/gds
# if [[ -d oas ]]; then
#   ln -s $PWD/data/oas/cara*oas data/caravel.oas
# else
#   ln -s $PWD/data/tapeout/outputs/oas/cara*_*oas data/caravel.oas
# fi
# mkdir -p data/work/gds
# cd data
# cp ../oas2gds.py .
# chown -R lvs:lvs .
# sudo -u lvs udocker run -i -t -v $PWD:$PWD \
#   -u $(id -u lvs):$(id -g lvs) \
#   efabless/mpw_precheck:latest bash -c "cd $PWD ; klayout -b -rm oas2gds.py"
# Out:
# export PDK_ROOT=/content/pdks
# export PDK=sky130B
# export PDKPATH=$PDK_ROOT/$PDK
# export PRECHECK_ROOT=/content/mpw_precheck
# export CARAVEL_ROOT=/content/caravel
# export UPRJ_ROOT=/content/data
# export LVS_ROOT=/content/extra_be_checks
#
# export MPW=mpw-005
# export SLOT=slot-002
# export TOP=user_project_wrapper
# unset WORK_ROOT
# Cloning into 'data'...
# remote: Total 1546 (delta 932), reused 1546 (delta 932)
# Receiving objects: 100% (1546/1546), 520.25 MiB | 27.37 MiB/s, done.
# Resolving deltas: 100% (932/932), done.
# Updating files: 100% (164/164), done.
# Info: creating repo: /home/lvs/.udocker
# Info: udocker command line interface 1.3.16
# Info: searching for udockertools >= 1.2.11
# Info: installing udockertools 1.2.11
# Info: installation of udockertools successful
# Info: downloading layer sha256:9ffd175d09c2931ac1d0689af8492615f7ea1cf9daece4427cb06d3e7caf78df
# Info: downloading layer sha256:1c995a21e29168ce44d4791f9dfe3b1e5ab4e0e79166fcd5ee8b563d6928dae1
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:95418c4554cc2fed8bf5cf5e5e3889ed002b9e98b8e8b5e66ca634d5aee7a67e
# Info: downloading layer sha256:918fcb05b91d6aae12079f212c95a9eadaef52927c9f9aa0f470382d4a638ec6
# Info: downloading layer sha256:82f52970b2cb9ee0fc0daf2175457ee968ff5407cb51345a94de828bc7bfc5c6
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:c4f05e1235591d388631e4cc9e1d1c15083a8f3161d68ab19a2cfbb321e0caf1
# Info: downloading layer sha256:da3efa1392fdfcea86d3ed01ec14b32eaad02d1b450c83ece44cc15a91ee94da
# Info: downloading layer sha256:b176683b983e31cf04eb75ad33b2f3224a8d4afc23d1e46ae97f22360c7585d5
# Info: downloading layer sha256:766d80c658004b59d642ee343a99828a5bdf43f3e4cbc918b5fb3ea053588f19
# Info: downloading layer sha256:f4349fddaa1457a3a76f75bf297f61a7081b930425a6de769cd5ffab831825d4
# Info: downloading layer sha256:c91aa9267bcb33ff1afd16b92ea52c33fe8c5be211919f2593dfe16f18035e9e
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:c679eeb51218bfaaada351b16234f4867dfaf4239f0cb3ccbe8bed307879185c
# Info: downloading layer sha256:a8f93b23a3a4eda9eda102e720a6e6edcd20b50c0f62179d0ea529899bbe9bf1
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:81d6782ca23243a2b15ce08c61f48607d01af3d772ad647fe98db688745dbbdc
# Info: downloading layer sha256:ce4e3a6451d2fd4a28b2b3e004396b983f1a45420c0325a7fdb5153dd4431e82
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:57c0a43690ef1e4b74f2e5e62c55ef0cb8413c613d0055c1fd4f937310688ec1
# Info: downloading layer sha256:2bc2deaeb7b152baa80b7c953a9fc5c5d7bca8f4b3bf4af9b9f244d07b50cb63
# Info: downloading layer sha256:4fb843ebbd1f57ffa900f8e61f93e29a310802411ff1dacd311f2032278debe5
# Info: downloading layer sha256:f183a3d01e655abe302ee76683a843dfbf5c55f03e288d632b02f9c81bf354cc
# Info: downloading layer sha256:c021215f9aac13b00d19176f39805b76eaa8237fdc66bf17778c2a7aaaf35368
# Info: downloading layer sha256:fc192c551799573c4c5b02cc98a82ad2db556545564de447c7e4d67c917ff5fa
# Info: downloading layer sha256:2d473b07cdd5f0912cd6f1a703352c82b512407db6b05b43f2553732b55df3bc
#
#  ******************************************************************************
#  *                                                                            *
#  *               STARTING 8f274e8c-fa01-3d65-8231-99874a138a10                *
#  *                                                                            *
#  ******************************************************************************
#  executing: bash
# [INFO] Reading from caravel.oas
# [INFO] Writing work/gds/SJ_user_project_wrapper.gds.gz

# %% [markdown]
# # List verilog and spice files

# %%
# %%shell
# source /content/env
# cd data
# find . -name '*.spice'
# find . -name '*.v'
# Out:
# ./spi/lvs/user_project_wrapper.spice
# ./spi/lvs/user_proj_example.spice
# ./mpw_precheck/outputs/user_project_wrapper.filtered.v
# ./verilog/rtl/uprj_netlists.v
# ./verilog/rtl/main.v
# ./verilog/rtl/user_project_wrapper.v
# ./verilog/rtl/L1_cache.v
# ./verilog/rtl/user_proj_example.v
# ./verilog/rtl/memory_trace.v
# ./verilog/gl/user_project_wrapper.v
# ./verilog/gl/user_proj_example.v
# ./verilog/dv/la_test/la_test_tb.v
# ./tapeout/outputs/verilog/rtl/caravel.v
# ./tapeout/outputs/verilog/gl/gpio_defaults_block_0403.v
# ./tapeout/outputs/verilog/gl/gpio_defaults_block_1803.v
# ./tapeout/outputs/verilog/gl/caravel.v
# ./tapeout/outputs/verilog/gl/user_id_programming.v

# %% [markdown]
# # Create lvs_config.json
#
# Update the TOP_LAYOUT, LVS_SPICE_FILES, LVS_VERILOG_FILES, and LAYOUT_FILE for every design.
#
# Update the other parameters as needed.

# %%
# %%writefile lvs_config.json
# {
#         "STD_CELL_LIBRARY": "sky130_fd_sc_hd",
#         "INCLUDE_CONFIGS": [
#                 "$LVS_ROOT/tech/$PDK/lvs_config.base.json"
#         ],
#         "TOP_SOURCE": "$TOP",
#         "TOP_LAYOUT": "SJ_user_project_wrapper",
#         "EXTRACT_FLATGLOB": [
#                 ""
#         ],
#         "EXTRACT_ABSTRACT": [
#                 ""
#         ],
#         "LVS_FLATTEN": [
#                 ""
#         ],
#         "LVS_NOFLATTEN": [
#                 ""
#         ],
#         "LVS_IGNORE": [
#                 ""
#         ],
#         "LVS_SPICE_FILES": [
#                 ""
#         ],
#         "LVS_VERILOG_FILES": [
#                 "$UPRJ_ROOT/verilog/gl/user_proj_example.v",
#                 "$UPRJ_ROOT/verilog/gl/user_project_wrapper.v"
#         ],
#         "LAYOUT_FILE": "$UPRJ_ROOT/work/gds/SJ_user_project_wrapper.gds.gz"
# }
# Out:
# Writing lvs_config.json

# %% [markdown]
# # Run BE checks

# %%
# %%shell
# cat /content/env
# source /content/env
# cd data
# gdspath=$(ls work/gds/*project_wrapper.gds.gz)
# gdsfile=${gdspath##*/}
# layout=${gdsfile%%.gds.gz}
# source=${layout//[A-Z0-9][A-Z0-9]_}
# echo "Layout is $layout, source is $source"
# cp $LVS_ROOT/tech/$PDK/cvc.power.$source work/cvc.power.$layout
# cp ../lvs_config.json lvs_config.json
# export INPUT_DIRECTORY=$PWD
# sudo -u lvs udocker run -i -t -v $PRECHECK_ROOT:$PRECHECK_ROOT \
#   -v $INPUT_DIRECTORY:$INPUT_DIRECTORY \
#   -v $LVS_ROOT:$LVS_ROOT \
#   -v $PDK_ROOT:$PDK_ROOT \
#   -e INPUT_DIRECTORY=$INPUT_DIRECTORY \
#   -e PDK_PATH=$PDK_ROOT/$PDK \
#   -e PDK=$PDK \
#   -e TOP=$TOP \
#   -e PDK_ROOT=$PDK_ROOT \
#   -e UPRJ_ROOT=$UPRJ_ROOT \
#   -e PDKPATH=$PDKPATH \
#   -e LVS_ROOT=$LVS_ROOT \
#   -e WORK_ROOT=$INPUT_DIRECTORY/work \
#   -u $(id -u lvs):$(id -g lvs) \
#   efabless/mpw_precheck:latest bash -c "env; cd $INPUT_DIRECTORY ; $LVS_ROOT/run_be_checks lvs_config.json"
# gunzip -f work/cvc.error.gz
# head -1 work/cvc.oeb.report > work/cvc.oeb.sort.report
# tail -n +2 work/cvc.oeb.report | sort -k1,1n >> work/cvc.oeb.sort.report
# Out:
# Streaming output truncated to the last 5000 lines.
#   Class: sky130_fd_pr__nfet_01v8 instances:   8
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:  12
#   Class: sky130_fd_pr__special_nfet_01v8 instances:   4
# Circuit contains 16 nets.
#
# Circuit 1 contains 24 devices, Circuit 2 contains 24 devices.
# Circuit 1 contains 16 nets,    Circuit 2 contains 16 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__decap_3'
# Circuit SJ_QD_sky130_fd_sc_hd__decap_3 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 2 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__decap_3'
# Circuit SJ_QD_sky130_fd_sc_hd__decap_3 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 2 nets.
#
# Circuit 1 contains 2 devices, Circuit 2 contains 2 devices.
# Circuit 1 contains 2 nets,    Circuit 2 contains 2 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__decap_8'
# Circuit SJ_QD_sky130_fd_sc_hd__decap_8 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 2 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__decap_8'
# Circuit SJ_QD_sky130_fd_sc_hd__decap_8 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 2 nets.
#
# Circuit 1 contains 2 devices, Circuit 2 contains 2 devices.
# Circuit 1 contains 2 nets,    Circuit 2 contains 2 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nand2_1 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nand2_1 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 6 nets,    Circuit 2 contains 6 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__mux2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__mux2_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__mux2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__mux2_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__nor2_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__nor2_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 6 nets,    Circuit 2 contains 6 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkbuf_2'
# Circuit SJ_QD_sky130_fd_sc_hd__clkbuf_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkbuf_2'
# Circuit SJ_QD_sky130_fd_sc_hd__clkbuf_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 5 nets,    Circuit 2 contains 5 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__and2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__and2_1 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 7 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__and2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__and2_1 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 7 nets.
#
# Circuit 1 contains 6 devices, Circuit 2 contains 6 devices.
# Circuit 1 contains 7 nets,    Circuit 2 contains 7 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4b_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or4b_4 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4b_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or4b_4 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a22o_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a22o_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a22o_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a22o_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 11 nets,    Circuit 2 contains 11 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkinv_4'
# Circuit SJ_QD_sky130_fd_sc_hd__clkinv_4 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkinv_4'
# Circuit SJ_QD_sky130_fd_sc_hd__clkinv_4 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 2 devices, Circuit 2 contains 2 devices.
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkbuf_4'
# Circuit SJ_QD_sky130_fd_sc_hd__clkbuf_4 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkbuf_4'
# Circuit SJ_QD_sky130_fd_sc_hd__clkbuf_4 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 5 nets,    Circuit 2 contains 5 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nor2_1 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor2_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nor2_1 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 6 nets,    Circuit 2 contains 6 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__buf_2'
# Circuit SJ_QD_sky130_fd_sc_hd__buf_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__buf_2'
# Circuit SJ_QD_sky130_fd_sc_hd__buf_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 5 nets,    Circuit 2 contains 5 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3b_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or3b_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 10 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3b_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or3b_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 10 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 10 nets,    Circuit 2 contains 10 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o21a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o21a_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o21a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o21a_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21bo_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21bo_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 10 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21bo_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21bo_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 10 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 10 nets,    Circuit 2 contains 10 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o22a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o22a_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o22a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o22a_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 11 nets,    Circuit 2 contains 11 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o32a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o32a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o32a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o32a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 13 nets,    Circuit 2 contains 13 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or4_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or4_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 11 nets,    Circuit 2 contains 11 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__dfxtp_2'
# Circuit SJ_QD_sky130_fd_sc_hd__dfxtp_2 contains 24 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   8
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:  12
#   Class: sky130_fd_pr__special_nfet_01v8 instances:   4
# Circuit contains 16 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__dfxtp_2'
# Circuit SJ_QD_sky130_fd_sc_hd__dfxtp_2 contains 24 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   8
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:  12
#   Class: sky130_fd_pr__special_nfet_01v8 instances:   4
# Circuit contains 16 nets.
#
# Circuit 1 contains 24 devices, Circuit 2 contains 24 devices.
# Circuit 1 contains 16 nets,    Circuit 2 contains 16 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o2111a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o2111a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o2111a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o2111a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 13 nets,    Circuit 2 contains 13 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkinv_2'
# Circuit SJ_QD_sky130_fd_sc_hd__clkinv_2 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkinv_2'
# Circuit SJ_QD_sky130_fd_sc_hd__clkinv_2 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 2 devices, Circuit 2 contains 2 devices.
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211ai_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o211ai_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211ai_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o211ai_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 10 nets,    Circuit 2 contains 10 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand4_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nand4_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand4_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nand4_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 10 nets,    Circuit 2 contains 10 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or3_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or3_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o2bb2a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o2bb2a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o2bb2a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o2bb2a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or2_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or2_4 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 7 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or2_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or2_4 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 7 nets.
#
# Circuit 1 contains 6 devices, Circuit 2 contains 6 devices.
# Circuit 1 contains 7 nets,    Circuit 2 contains 7 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor4_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nor4_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor4_1'
# Circuit SJ_QD_sky130_fd_sc_hd__nor4_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 10 nets,    Circuit 2 contains 10 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21o_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21o_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21o_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21o_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__or2_2 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 7 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__or2_2 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 7 nets.
#
# Circuit 1 contains 6 devices, Circuit 2 contains 6 devices.
# Circuit 1 contains 7 nets,    Circuit 2 contains 7 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3_2'
# Circuit SJ_QD_sky130_fd_sc_hd__or3_2 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3_2'
# Circuit SJ_QD_sky130_fd_sc_hd__or3_2 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__dfxtp_4'
# Circuit SJ_QD_sky130_fd_sc_hd__dfxtp_4 contains 24 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   8
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:  12
#   Class: sky130_fd_pr__special_nfet_01v8 instances:   4
# Circuit contains 16 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__dfxtp_4'
# Circuit SJ_QD_sky130_fd_sc_hd__dfxtp_4 contains 24 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   8
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:  12
#   Class: sky130_fd_pr__special_nfet_01v8 instances:   4
# Circuit contains 16 nets.
#
# Circuit 1 contains 24 devices, Circuit 2 contains 24 devices.
# Circuit 1 contains 16 nets,    Circuit 2 contains 16 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__mux2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__mux2_2 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__mux2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__mux2_2 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o211a_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o211a_1 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 11 nets,    Circuit 2 contains 11 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__buf_12'
# Circuit SJ_QD_sky130_fd_sc_hd__buf_12 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__buf_12'
# Circuit SJ_QD_sky130_fd_sc_hd__buf_12 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 5 nets,    Circuit 2 contains 5 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__mux2_8'
# Circuit SJ_QD_sky130_fd_sc_hd__mux2_8 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__mux2_8'
# Circuit SJ_QD_sky130_fd_sc_hd__mux2_8 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__dlymetal6s2s_1'
# Circuit SJ_QD_sky130_fd_sc_hd__dlymetal6s2s_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__dlymetal6s2s_1'
# Circuit SJ_QD_sky130_fd_sc_hd__dlymetal6s2s_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 9 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkbuf_16'
# Circuit SJ_QD_sky130_fd_sc_hd__clkbuf_16 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkbuf_16'
# Circuit SJ_QD_sky130_fd_sc_hd__clkbuf_16 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 5 nets,    Circuit 2 contains 5 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a31o_2'
# Circuit SJ_QD_sky130_fd_sc_hd__a31o_2 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a31o_2'
# Circuit SJ_QD_sky130_fd_sc_hd__a31o_2 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 11 nets,    Circuit 2 contains 11 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkinv_16'
# Circuit SJ_QD_sky130_fd_sc_hd__clkinv_16 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__clkinv_16'
# Circuit SJ_QD_sky130_fd_sc_hd__clkinv_16 contains 2 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   1
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 2 devices, Circuit 2 contains 2 devices.
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand2_8'
# Circuit SJ_QD_sky130_fd_sc_hd__nand2_8 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand2_8'
# Circuit SJ_QD_sky130_fd_sc_hd__nand2_8 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 6 nets,    Circuit 2 contains 6 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o41a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o41a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o41a_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o41a_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 13 nets,    Circuit 2 contains 13 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4b_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or4b_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4b_1'
# Circuit SJ_QD_sky130_fd_sc_hd__or4b_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 12 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or4_4 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or4_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or4_4 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 11 nets,    Circuit 2 contains 11 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor4_2'
# Circuit SJ_QD_sky130_fd_sc_hd__nor4_2 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nor4_2'
# Circuit SJ_QD_sky130_fd_sc_hd__nor4_2 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 10 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 10 nets,    Circuit 2 contains 10 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__buf_4'
# Circuit SJ_QD_sky130_fd_sc_hd__buf_4 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__buf_4'
# Circuit SJ_QD_sky130_fd_sc_hd__buf_4 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 5 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 5 nets,    Circuit 2 contains 5 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a32o_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a32o_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a32o_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a32o_1 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   6
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   6
# Circuit contains 13 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 13 nets,    Circuit 2 contains 13 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21oi_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21oi_1 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 8 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21oi_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21oi_1 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 8 nets.
#
# Circuit 1 contains 6 devices, Circuit 2 contains 6 devices.
# Circuit 1 contains 8 nets,    Circuit 2 contains 8 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o21ai_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o21ai_1 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 8 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o21ai_1'
# Circuit SJ_QD_sky130_fd_sc_hd__o21ai_1 contains 6 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   3
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   3
# Circuit contains 8 nets.
#
# Circuit 1 contains 6 devices, Circuit 2 contains 6 devices.
# Circuit 1 contains 8 nets,    Circuit 2 contains 8 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21boi_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21boi_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__a21boi_1'
# Circuit SJ_QD_sky130_fd_sc_hd__a21boi_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__and3_1'
# Circuit SJ_QD_sky130_fd_sc_hd__and3_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__and3_1'
# Circuit SJ_QD_sky130_fd_sc_hd__and3_1 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211ai_4'
# Circuit SJ_QD_sky130_fd_sc_hd__o211ai_4 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   8
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211ai_4'
# Circuit SJ_QD_sky130_fd_sc_hd__o211ai_4 contains 12 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   8
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 12 nets.
#
# Circuit 1 contains 12 devices, Circuit 2 contains 12 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or3_4 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__or3_4'
# Circuit SJ_QD_sky130_fd_sc_hd__or3_4 contains 8 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   4
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   4
# Circuit contains 9 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 9 nets,    Circuit 2 contains 9 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211a_2'
# Circuit SJ_QD_sky130_fd_sc_hd__o211a_2 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__o211a_2'
# Circuit SJ_QD_sky130_fd_sc_hd__o211a_2 contains 10 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   5
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   5
# Circuit contains 11 nets.
#
# Circuit 1 contains 10 devices, Circuit 2 contains 10 devices.
# Circuit 1 contains 11 nets,    Circuit 2 contains 11 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__nand2_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_sky130_fd_sc_hd__nand2_2'
# Circuit SJ_QD_sky130_fd_sc_hd__nand2_2 contains 4 device instances.
#   Class: sky130_fd_pr__nfet_01v8 instances:   2
#   Class: sky130_fd_pr__pfet_01v8_hvt instances:   2
# Circuit contains 6 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 6 nets,    Circuit 2 contains 6 nets.
#
#
# Contents of circuit 1:  Circuit: 'SJ_QD_user_proj_example'
# Circuit SJ_QD_user_proj_example contains 39907 device instances.
#   Class: SJ_QD_sky130_fd_sc_hd__or3b_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o221a_1 instances: 254
#   Class: SJ_QD_sky130_fd_sc_hd__nand4_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a32o_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o41a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a22o_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__o2111a_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o21a_1 instances:  11
#   Class: SJ_QD_sky130_fd_sc_hd__o2bb2a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__or2_1 instances:  37
#   Class: SJ_QD_sky130_fd_sc_hd__or2_2 instances:   9
#   Class: SJ_QD_sky130_fd_sc_hd__or2_4 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_1 instances:  43
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_2 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_16 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o21ai_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a31o_2 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__decap_12 instances: 26084
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_4 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21o_1 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__a21bo_1 instances:  13
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_16 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__dlymetal6s2s_1 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__decap_3 instances: 666
#   Class: SJ_QD_sky130_fd_sc_hd__decap_4 instances: 4324
#   Class: SJ_QD_sky130_fd_sc_hd__decap_6 instances: 6275
#   Class: SJ_QD_sky130_fd_sc_hd__decap_8 instances: 283
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_1 instances: 359
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_2 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_4 instances:  14
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_1 instances:  10
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_8 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_1 instances: 117
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_2 instances: 160
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_4 instances:  10
#   Class: SJ_QD_sky130_fd_sc_hd__and3_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21boi_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_2 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_4 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_1 instances: 552
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_2 instances:  11
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_8 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__or4_1 instances:  12
#   Class: SJ_QD_sky130_fd_sc_hd__or4_4 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__buf_2 instances:  68
#   Class: SJ_QD_sky130_fd_sc_hd__buf_4 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__and2_1 instances: 102
#   Class: SJ_QD_sky130_fd_sc_hd__or4b_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__or4b_4 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__nor4_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__nor4_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21oi_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o32a_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o22a_1 instances:  64
#   Class: SJ_QD_sky130_fd_sc_hd__inv_2 instances: 249
#   Class: SJ_QD_sky130_fd_sc_hd__buf_12 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__or3_1 instances:  12
#   Class: SJ_QD_sky130_fd_sc_hd__or3_2 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__or3_4 instances:   1
# Circuit contains 2279 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_user_proj_example'
# Circuit SJ_QD_user_proj_example contains 39907 device instances.
#   Class: SJ_QD_sky130_fd_sc_hd__or3b_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o221a_1 instances: 254
#   Class: SJ_QD_sky130_fd_sc_hd__nand4_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a32o_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o41a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a22o_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__o2111a_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o21a_1 instances:  11
#   Class: SJ_QD_sky130_fd_sc_hd__o2bb2a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__or2_1 instances:  37
#   Class: SJ_QD_sky130_fd_sc_hd__or2_2 instances:   9
#   Class: SJ_QD_sky130_fd_sc_hd__or2_4 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_1 instances:  43
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_2 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_16 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o21ai_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a31o_2 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__decap_12 instances: 26084
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_4 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21o_1 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__a21bo_1 instances:  13
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_16 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__dlymetal6s2s_1 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__decap_3 instances: 666
#   Class: SJ_QD_sky130_fd_sc_hd__decap_4 instances: 4324
#   Class: SJ_QD_sky130_fd_sc_hd__decap_6 instances: 6275
#   Class: SJ_QD_sky130_fd_sc_hd__decap_8 instances: 283
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_1 instances: 359
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_2 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_4 instances:  14
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_1 instances:  10
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_8 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_1 instances: 117
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_2 instances: 160
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_4 instances:  10
#   Class: SJ_QD_sky130_fd_sc_hd__and3_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21boi_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_2 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_4 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_1 instances: 552
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_2 instances:  11
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_8 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__or4_1 instances:  12
#   Class: SJ_QD_sky130_fd_sc_hd__or4_4 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__buf_2 instances:  68
#   Class: SJ_QD_sky130_fd_sc_hd__buf_4 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__and2_1 instances: 102
#   Class: SJ_QD_sky130_fd_sc_hd__or4b_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__or4b_4 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__nor4_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__nor4_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21oi_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o32a_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o22a_1 instances:  64
#   Class: SJ_QD_sky130_fd_sc_hd__inv_2 instances: 249
#   Class: SJ_QD_sky130_fd_sc_hd__buf_12 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__or3_1 instances:  12
#   Class: SJ_QD_sky130_fd_sc_hd__or3_2 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__or3_4 instances:   1
# Circuit contains 2279 nets.
#
# Circuit was modified by parallel/series device merging.
# New circuit summary:
#
# Contents of circuit 1:  Circuit: 'SJ_QD_user_proj_example'
# Circuit SJ_QD_user_proj_example contains 2280 device instances.
#   Class: SJ_QD_sky130_fd_sc_hd__or3b_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o221a_1 instances: 254
#   Class: SJ_QD_sky130_fd_sc_hd__nand4_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a32o_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o41a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a22o_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__o2111a_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o21a_1 instances:  11
#   Class: SJ_QD_sky130_fd_sc_hd__o2bb2a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__or2_1 instances:  37
#   Class: SJ_QD_sky130_fd_sc_hd__or2_2 instances:   9
#   Class: SJ_QD_sky130_fd_sc_hd__or2_4 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_1 instances:  43
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_2 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_16 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o21ai_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a31o_2 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__decap_12 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_4 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21o_1 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__a21bo_1 instances:  13
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_16 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__dlymetal6s2s_1 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__decap_3 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__decap_4 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__decap_6 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__decap_8 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_1 instances: 359
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_2 instances:   5
#   Class: SJ_QD_sky130_fd_sc_hd__dfxtp_4 instances:  14
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_1 instances:  10
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__nand2_8 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_1 instances: 117
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_2 instances: 160
#   Class: SJ_QD_sky130_fd_sc_hd__clkbuf_4 instances:  10
#   Class: SJ_QD_sky130_fd_sc_hd__and3_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21boi_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_2 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_4 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_1 instances: 552
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_2 instances:  11
#   Class: SJ_QD_sky130_fd_sc_hd__mux2_8 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__or4_1 instances:  12
#   Class: SJ_QD_sky130_fd_sc_hd__or4_4 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__buf_2 instances:  68
#   Class: SJ_QD_sky130_fd_sc_hd__buf_4 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__and2_1 instances: 102
#   Class: SJ_QD_sky130_fd_sc_hd__or4b_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__or4b_4 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__nor4_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__nor4_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a21oi_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o32a_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o22a_1 instances:  64
#   Class: SJ_QD_sky130_fd_sc_hd__inv_2 instances: 249
#   Class: SJ_QD_sky130_fd_sc_hd__buf_12 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__or3_1 instances:  12
#   Class: SJ_QD_sky130_fd_sc_hd__or3_2 instances:   3
#   Class: SJ_QD_sky130_fd_sc_hd__or3_4 instances:   1
# Circuit contains 2279 nets.
# Contents of circuit 2:  Circuit: 'SJ_QD_user_proj_example'
# Circuit SJ_QD_user_proj_example contains 2280 device instances.
#   Class: SJ_QD_sky130_fd_sc_hd__or3b_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o221a_1 instances: 254
#   Class: SJ_QD_sky130_fd_sc_hd__nand4_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_1 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__o211a_2 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__a32o_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o41a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a22o_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__o2111a_1 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o21a_1 instances:  11
#   Class: SJ_QD_sky130_fd_sc_hd__o2bb2a_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__or2_1 instances:  37
#   Class: SJ_QD_sky130_fd_sc_hd__or2_2 instances:   9
#   Class: SJ_QD_sky130_fd_sc_hd__or2_4 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_1 instances:  43
#   Class: SJ_QD_sky130_fd_sc_hd__nor2_2 instances:   2
#   Class: SJ_QD_sky130_fd_sc_hd__clkinv_16 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__o21ai_1 instances:   4
#   Class: SJ_QD_sky130_fd_sc_hd__a31o_2 instances:   6
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_1 instances:  27
#   Class: SJ_QD_sky130_fd_sc_hd__decap_12 instances:   1
#   Class: SJ_QD_sky130_fd_sc_hd__o211ai_4 instances:   1
# ...
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[4]
#
# > gn io_in[4]
# Net io_in[4]: 631
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[5]
#
# > gn io_in[5]
# Net io_in[5]: 633
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[6]
#
# > gn io_in[6]
# Net io_in[6]: 621
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[7]
#
# > gn io_in[7]
# Net io_in[7]: 634
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[8]
#
# > gn io_in[8]
# Net io_in[8]: 626
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[9]
#
# > gn io_in[9]
# Net io_in[9]: 554
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[10]
#
# > gn io_in[10]
# Net io_in[10]: 547
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[11]
#
# > gn io_in[11]
# Net io_in[11]: 559
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[12]
#
# > gn io_in[12]
# Net io_in[12]: 544
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[13]
#
# > gn io_in[13]
# Net io_in[13]: 552
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[14]
#
# > gn io_in[14]
# Net io_in[14]: 561
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[15]
#
# > gn io_in[15]
# Net io_in[15]: 2
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[16]
#
# > gn io_in[16]
# Net io_in[16]: 16
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[17]
#
# > gn io_in[17]
# Net io_in[17]: 7
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[18]
#
# > gn io_in[18]
# Net io_in[18]: 11
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[19]
#
# > gn io_in[19]
# Net io_in[19]: 1
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[20]
#
# > gn io_in[20]
# Net io_in[20]: 26
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[21]
#
# > gn io_in[21]
# Net io_in[21]: 29
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[22]
#
# > gn io_in[22]
# Net io_in[22]: 35
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[23]
#
# > gn io_in[23]
# Net io_in[23]: 28
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[24]
#
# > gn io_in[24]
# Net io_in[24]: 578
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[25]
#
# > gn io_in[25]
# Net io_in[25]: 587
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[26]
#
# > gn io_in[26]
# Net io_in[26]: 574
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[27]
#
# > gn io_in[27]
# Net io_in[27]: 564
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[28]
#
# > gn io_in[28]
# Net io_in[28]: 586
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[29]
#
# > gn io_in[29]
# Net io_in[29]: 568
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[30]
#
# > gn io_in[30]
# Net io_in[30]: 565
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[31]
#
# > gn io_in[31]
# Net io_in[31]: 602
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[32]
#
# > gn io_in[32]
# Net io_in[32]: 604
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[33]
#
# > gn io_in[33]
# Net io_in[33]: 600
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[34]
#
# > gn io_in[34]
# Net io_in[34]: 613
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[35]
#
# > gn io_in[35]
# Net io_in[35]: 608
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[36]
#
# > gn io_in[36]
# Net io_in[36]: 606
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn io_in[37]
#
# > gn io_in[37]
# Net io_in[37]: 593
#  connections: gate 0 source 0 drain 0 bulk 0
#  base definition io_in[*]
#   default min unknown
#   default sim unknown
#   default max unknown
#  defined as  input min@0.0 max@1.8 =>  min@0.0 max@1.8 input
#
# ** Stage 7/7: Enter command ?> gn analog_io[0]
#
# > gn analog_io[0]
# Net analog_io[0]: 619
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[1]
#
# > gn analog_io[1]
# Net analog_io[1]: 628
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[2]
#
# > gn analog_io[2]
# Net analog_io[2]: 562
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[3]
#
# > gn analog_io[3]
# Net analog_io[3]: 539
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[4]
#
# > gn analog_io[4]
# Net analog_io[4]: 546
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[5]
#
# > gn analog_io[5]
# Net analog_io[5]: 549
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[6]
#
# > gn analog_io[6]
# Net analog_io[6]: 548
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[7]
#
# > gn analog_io[7]
# Net analog_io[7]: 553
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[8]
#
# > gn analog_io[8]
# Net analog_io[8]: 8
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[9]
#
# > gn analog_io[9]
# Net analog_io[9]: 4
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[10]
#
# > gn analog_io[10]
# Net analog_io[10]: 9
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[11]
#
# > gn analog_io[11]
# Net analog_io[11]: 15
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[12]
#
# > gn analog_io[12]
# Net analog_io[12]: 6
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[13]
#
# > gn analog_io[13]
# Net analog_io[13]: 27
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[14]
#
# > gn analog_io[14]
# Net analog_io[14]: 21
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[15]
#
# > gn analog_io[15]
# Net analog_io[15]: 20
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[16]
#
# > gn analog_io[16]
# Net analog_io[16]: 24
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[17]
#
# > gn analog_io[17]
# Net analog_io[17]: 575
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[18]
#
# > gn analog_io[18]
# Net analog_io[18]: 572
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[19]
#
# > gn analog_io[19]
# Net analog_io[19]: 573
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[20]
#
# > gn analog_io[20]
# Net analog_io[20]: 577
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[21]
#
# > gn analog_io[21]
# Net analog_io[21]: 571
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[22]
#
# > gn analog_io[22]
# Net analog_io[22]: 580
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[23]
#
# > gn analog_io[23]
# Net analog_io[23]: 579
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[24]
#
# > gn analog_io[24]
# Net analog_io[24]: 599
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[25]
#
# > gn analog_io[25]
# Net analog_io[25]: 601
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[26]
#
# > gn analog_io[26]
# Net analog_io[26]: 603
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[27]
#
# > gn analog_io[27]
# Net analog_io[27]: 614
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> gn analog_io[28]
#
# > gn analog_io[28]
# Net analog_io[28]: 597
#  connections: gate 0 source 0 drain 0 bulk 0
#
# ** Stage 7/7: Enter command ?> q
#
# > q
#  gpio |   in   |   out  | analog |  oeb min/sim/max  | Message
#   35  |        |        |        |      /     /      |
#   26  |        |        |        |      /     /      |
#   17  |        |        |        |      /     /      |
#    4  |        |        |        |      /     /      |
#   36  |        |        |        |      /     /      |
#   27  |        |        |        |      /     /      |
#   18  |        |        |        |      /     /      |
#    5  |        |        |        |      /     /      |
#   37  |        |        |        |      /     /      |
#   28  |        |        |        |      /     /      |
#   19  |        |        |        |      /     /      |
#    6  |        |        |        |      /     /      |
#   29  |        |        |        |      /     /      |
#    7  |        |        |        |      /     /      |
#    8  |        |        |        |      /     /      |
#    9  |        |        |        |      /     /      |
#   10  |        |        |        |      /     /      |
#   20  |        |        |        |      /     /      |
#   11  |        |        |        |      /     /      |
#   30  |        |        |        |      /     /      |
#   21  |        |        |        |      /     /      |
#   12  |        |        |        |      /     /      |
#   31  |        |        |        |      /     /      |
#   22  |        |        |        |      /     /      |
#   13  |        |        |        |      /     /      |
#    0  |        |        |        |      /     /      |
#   32  |        |        |        |      /     /      |
#   23  |        |        |        |      /     /      |
#   14  |        |        |        |      /     /      |
#    1  |        |        |        |      /     /      |
#   33  |        |        |        |      /     /      |
#   24  |        |        |        |      /     /      |
#   15  |        |        |        |      /     /      |
#    2  |        |        |        |      /     /      |
#   34  |        |        |        |      /     /      |
#   25  |        |        |        |      /     /      |
#   16  |        |        |        |      /     /      |
#    3  |        |        |        |      /     /      |
#
# Soft check result:
# Final result:
# Circuits match uniquely.
# .
#
# LVS result:
# Final result:
# Circuits match uniquely.
# .
# LVS Done.
#
# CVC result:
# CVC: Total:                 0
#
# OEB check result: ERRORS: 0  Warnings: 0
#
# Runtime: 0:03:28 (hh:mm:ss)
#
# No errors detected
# gzip: work/cvc.error already exists; do you wish to overwrite (y or n)? y

# %% [markdown]
# # View verification logs

# %%
from google.colab import files

files.view('/content/data/work/soft.log')
files.view('/content/data/work/lvs.log')
files.view('/content/data/work/cvc.log')
files.view('/content/data/work/cvc.oeb.log')

# %% [markdown]
# # View soft verification report

# %%
from google.colab import files

files.view('/content/data/work/soft.report')

# %% [markdown]
# # View LVS report

# %%
from google.colab import files

files.view('/content/data/work/lvs.report')

# %% [markdown]
# # View CVC report

# %%
from google.colab import files

files.view('/content/data/work/cvc.error')

# %% [markdown]
# # View OEB report

# %%
from google.colab import files

files.view('/content/data/work/cvc.oeb.sort.report')
